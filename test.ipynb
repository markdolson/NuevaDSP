# %%
import matplotlib
matplotlib.use("nbagg")
import matplotlib.pyplot as plt
import dsp_signal
#%matplotlib notebook
# Out:
# /home/emily/anaconda3/lib/python3.4/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
a = dsp_signal.Signal([1,2,3])
print(a)
# Out:
# [[1 2 3]]

# %%
a.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dsp_signal.plot_signal(a+a)
dsp_signal.plot_signal(a)
dsp_signal.plot_signal(a*a)
plt.show()
# Out:
# [ 0.        0.000125  0.00025 ]
# [ 0.        0.000125  0.00025 ]
# [ 0.        0.000125  0.00025 ]
# <img src="data:image/png;base64,...">

# %%
dsp_signal.plot_signal(a)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
